# %% [markdown]
# # Hate Speech on Twitter
# ## Deliverable 02
# ## Amir ElTabakh
# ## 3/11/2022
#
# This document primarily focuses on accessing the Twitter API, the privileges we have to work with, extended privileges for when we are ready to move forward with our analysis, how we can query Twitter searches, and identifying the features we have to work with.
#
# ### Agenda
# - Identifying the privileges we have to work with and extended privileges
# - Accessing the twitter API with Python.
# - Identifying the features/variables available through the Twitter API, and defining them.
# - Practice filtering for specific hashtags, such as "#ChineseVirus"
#
# ## The Twitter API
# Refer to the [Getting Started](https://developer.twitter.com/en/docs/platform-overview) page on the Twitter Developer Platform site so sign up for the twitter API. This shit be smooth sailing. There are three products we can access through the Twitter API. We now have access to the Elevated product.
#
# #### Essential
# Free and immediate access to the Twitter API. No application is required.
#
# - 1 environment per project (irrelevant)
# - 500K tweets per month/project
# - Cost: free
#
# #### Elevated
# Higher levels of access to the Twitter API for free with an approved application.
#
# - 3 environments per project (irrelevant)
# - 2M tweets per month/project
# - Cost: free
#
# #### Academic Research
# For academics who have a research project that requires, or would benefit from, studying Twitter’s conversational data. Access is free. An application is required.
#
# - 1 environments per project (irrelevant)
# - 10M tweets per month/project
# - Cost: free
# - For non-commercial use only
#
# ### Search Tweets
#
# We will primarily be utilizing the [Search Tweets](https://developer.twitter.com/en/docs/twitter-api/tweets/search/introduction) features.
#
# Searching for Tweets is an important feature used to surface Twitter conversations about a specific topic or event. While this functionality is present in Twitter, these endpoints provide greater flexibility and power when filtering for and ingesting Tweets so you can find relevant data for your research more easily; build out near-real-time ‘listening’ applications; or generally explore, analyze, and/or act upon Tweets related to a topic of interest.
#
# Twitter offers two endpoints that allow you to search for Tweets: Recent search and full-archive search. Both of these REST endpoints share a common design and features, including their use of a single search query to filter for Tweets around a specific topic. These search queries are created with a set of operators that match on Tweet and user attributes, such as message keywords, hashtags, and URLs. Operators can be combined into queries with boolean logic and parentheses to help refine the queries matching behavior.
#
# Once you’ve set up your query and start receiving Tweets, these endpoints support navigating the results both by time and Tweet ID ranges. This is designed to support two common use cases:
#
# - **Get historical**: Requests are for a period of interest, with no focus on the real-time nature of the data. A single request is made, and all matching data is delivered using pagination as needed. This is the default mode for Search Tweets.
# - **Polling or listening**: Requests are made in a "any new Tweets since my last request?" mode. Requests are made on a continual basis, and typically there is a use case focused on near real-time 'listening' for Tweets of interest.
#
# Many operators and query limits are exclusive to Academic Research access, meaning that you must use keys and tokens from an App within a Project with Academic Research access to utilize the additional functionality. You can learn more about this in the endpoint sections below. Both the recent search and the full-archive search endpoints returned Tweets contribute to the monthly Tweet cap.
#
# Now let's go over the two endpoints provided.
#
# #### Recent search
# The recent search endpoint allows you to programmatically access filtered public Tweets posted over the last week, and is available to all developers who have a developer account and are using keys and tokens from an App within a Project.
#
# You can authenticate your requests with OAuth 1.0a User Context, OAuth 2.0 App-Only, or OAuth 2.0 Authorization Code with PKCE. However, if you would like to receive private metrics, or a breakdown of organic and promoted metrics within your Tweet results, you will have to use OAuth 1.0a User Context or OAuth 2.0 Authorization Code with PKCE, and pass user Access Tokens that are associated with the user that published the given content.
#
# This endpoint can deliver up to 100 Tweets per request in reverse-chronological order, and pagination tokens are provided for paging through large sets of matching Tweets.
#
# When using a Project with Essential or Elevated access, you can use the basic set of operators and can make queries up to 512 characters long. When using a Project with Academic Research access, you have access to additional operators and can make queries up to 1024 characters long.
#
# #### Full-archive search
# *Academic Research access only*
#
# The v2 full-archive search endpoint is only available to Projects with Academic Research access. The endpoint allows you to programmatically access public Tweets from the complete archive dating back to the first Tweet in March 2006, based on your search query.
#
# You can authenticate your requests to this endpoint using OAuth 2.0 App-Only, and the App Access Token must come from an App that is within a Project that has Academic Research access. Since you cannot make a request on behalf of other users (OAuth 1.0a User Context or OAuth 2.0 Authorization Code with PKCE) with this endpoint, you will not be able to pull private metrics.
#
# This endpoint can deliver up to 500 Tweets per request in reverse-chronological order, and pagination tokens are provided for paging through large sets of matching Tweets.
#
# Since this endpoint is only available to those that have been approved for Academic Research access, you have access to the full set of search operators and can make queries up to 1024 characters long.
#
# ## Accessing the Twitter API with Python
#
# Let's get our hands dirty with some code. I have applied to a Twitter Developer Account and I have my API key and API key secret stored in a seperate document, I will import it below. But first, lets introduce [Tweepy](https://www.tweepy.org/). Tweepy is an easy-to-use Python library for accessing the Twitter API. Let's pip install it so it is accessible in our environment. Note that you only have to pip install tweepy (or any library) once, but you will have to import it in every instance you need it.

# %%
# pip install tweepy (use either or)
#!pip install tweep
# !python -m pip install git+https://github.com/tweepy/tweepy@master
# Out:
# Collecting git+https://github.com/tweepy/tweepy@master
#   Cloning https://github.com/tweepy/tweepy (to revision master) to c:\users\amira\appdata\local\temp\pip-req-build-9uo9gm4y
# WARNING: Ignoring invalid distribution -tatsmodels (e:\users\amira\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\users\amira\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (e:\users\amira\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\users\amira\anaconda\lib\site-packages)
#   ERROR: Error [WinError 2] The system cannot find the file specified while executing command git version
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?
# WARNING: Ignoring invalid distribution -tatsmodels (e:\users\amira\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\users\amira\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (e:\users\amira\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (e:\users\amira\anaconda\lib\site-packages)

# %%
# importing dependencies
import tweepy as tw
import pandas as pd

# Twitter Keys, tokens, and secrets are saved in seperate config file on my local device
from config import consumer_key, consumer_secret, access_token, access_secret, bearer_token

# %% [markdown]
# Now that we have access to and have imported our API key and API key secret, we can initialize the tweepy OAuthHandler with the API key and the API secret and use it to get an instance of tweepy API class using which we’ll be making requests to the Twitter API.

# %%
# authenticate
auth = tw.OAuthHandler(consumer_key, consumer_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# A search query is simply a string telling the Twitter API what kind of tweets you want to search for. Imagine using the search bar on Twitter itself without the API. For example, if you want to search for tweets with "#chinesevirus", you’d simply type #chinesevirus in the Twitter search bar and it’ll show you those tweets.
#
# Under the hood, if we’re using a search query with Twitter API, it actually returns the results from what you’d get had you searched for it directly on Twitter. The difference here is we can query for thousands, or millions of tweets, access other metadata about the tweets, and get to work analyzing and generating products with the data.

# %%
search_query = "#chinesevirus -filter:retweets"

# %% [markdown]
# Here we set up our search_query to fetch tweets with `#chinesevirus` but also filter out the retweets. You can customize your query based on your requirements. For more, refer to [this guide](https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/guides/standard-operators).
#
# We can query exact phrases, we could add an 'or' clause, a 'minus' clause to query strings not containing a string, we can query hashtags, tweets sent from specific twitter accounts, a tweet authored tin reply to an account, tweets mentioning accounts, we can filter for or against tweets marked as potentially sensitive, tweets containing images and/or videos, tweets containing URLs (you can filter for strings inside the URL as well), you can filter for tweets sent before a date or since a date, you can filter for tweets containing positive attitudes or negative attitudes, and you can filter for tweets containing questions.
#
# ^ A lot I know, but these may come in handy when figuring out how we want to target our tweets.
#
# Now that we can access the API, we will build the request for the endpoint we are going to use and the parameters we want to pass.

# %%
# get tweets from the API
tweets = tw.Cursor(api.search_tweets,
              q=search_query,
              lang="en",
              since="2022-02-25").items(10)

# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    print(tweet.text, '\n\n')
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Unexpected parameter: since
# #Bengaluru After a long time (thanks to the #ChineseVirus) how about a #TweetUp
# (Venue can be decided based on the… https://t.co/sYRZceBf5c
#
#
# @PTI_News China will keep playing this bogie as #Putin has taken away entire attention from the #ChineseVirus.
#
#
# In view of the spread of new virus,
# China has imposed a lockdown in the north-eastern industrial center of Changch… https://t.co/zRaZbsZrGJ
#
#
# @amitsurg So a minister will decide if the prescription is right?
# The biggest tragedy following #ChineseVirus pande… https://t.co/fqMPoaZ2F1
#
#
# @jaideepsethiya @OpIndia_com Whatever the ranking we're No:1
#
# Terrorist exports, #ChineseVirus, gold and drug smugg… https://t.co/JRhm25NlNy
#
#
# "Chinese cyberespionage group Mustang Panda has been targeting European diplomats with an updated variant of the Pl… https://t.co/O5Gj8WHV5K
#
#
# @JackDetsch Well, China came first with #chinesevirus. Russia must think another thing for a surprise.
#
#
# @UNICEFIndia Stay safe from #ChineseVirus
#
#
# Latest evidence founded at US biological lab in Ukraine shows the fucking virus was made by fucking American. And o… https://t.co/t89DtNe0K5
#
#
# America post-freedom:
#
# Day 414 of fake election winners
#
# Week 103 of two weeks to flatten the curve
#
# #TrumpWon2020… https://t.co/V6KLmgTWe3
#
#
# Total Tweets fetched: 10

# %%
# snapshot of how a single tweet looks like
tweets_copy[0]._json
# Out:
# {'created_at': 'Fri Mar 11 15:21:56 +0000 2022',
#  'id': 1502303819740319746,
#  'id_str': '1502303819740319746',
#  'text': '#Bengaluru After a long time (thanks to the #ChineseVirus) how about a #TweetUp \n(Venue can be decided based on the… https://t.co/sYRZceBf5c',
#  'truncated': True,
#  'entities': {'hashtags': [{'text': 'Bengaluru', 'indices': [0, 10]},
#    {'text': 'ChineseVirus', 'indices': [44, 57]},
#    {'text': 'TweetUp', 'indices': [71, 79]}],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/sYRZceBf5c',
#     'expanded_url': 'https://twitter.com/i/web/status/1502303819740319746',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 49877768,
#   'id_str': '49877768',
#   'name': 'Suresh 🇮🇳',
#   'screen_name': 'surnell',
#   'location': 'Bengaluru, India',
#   'description': '#SkillIndia #IoT #AutomobileIT #CyberForensics & Law. \n|Credo: Fix Media and Fake RWers, to Fix India| 𝗛𝗮𝗽𝗽𝘆 𝗳𝗼𝗿 𝗡𝗼 𝗥𝗲𝗮𝘀𝗼𝗻 😊|',
#   'url': 'https://t.co/t1VwK8Rrdz',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/t1VwK8Rrdz',
#       'expanded_url': 'https://yensures.com/about//',
#       'display_url': 'yensures.com/about//',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 68563,
#   'friends_count': 2058,
#   'listed_count': 285,
#   'created_at': 'Tue Jun 23 03:57:35 +0000 2009',
#   'favourites_count': 859,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 285862,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '1A1B1F',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1498119015176478720/XNTPbXCU_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1498119015176478720/XNTPbXCU_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49877768/1645496950',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '252429',
#   'profile_text_color': '666666',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 2,
#  'favorite_count': 35,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
# Number of columns
len(tweets_copy[0]._json.keys())
# Out:
# 24

# %%
# Let's see all the features available to us
tweets_copy[0]._json.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
# Lets create a dataframe for our scraped tweets
df = pd.DataFrame(columns = tweets_copy[0]._json.keys())

for i in range(len(tweets_copy)):
    df = df.append(pd.json_normalize(tweets_copy[i]._json))
    
df.reset_index()
df
# Out:
#                        created_at                   id               id_str  \
# 0  Fri Mar 11 15:21:56 +0000 2022  1502303819740319746  1502303819740319746
# 0  Fri Mar 11 14:47:40 +0000 2022  1502295193806163968  1502295193806163968
# 0  Fri Mar 11 14:40:16 +0000 2022  1502293335062433793  1502293335062433793
# 0  Fri Mar 11 13:32:12 +0000 2022  1502276202635329538  1502276202635329538
# 0  Fri Mar 11 12:25:04 +0000 2022  1502259310587351041  1502259310587351041
# 0  Thu Mar 10 20:47:27 +0000 2022  1502023348464893955  1502023348464893955
# 0  Thu Mar 10 20:11:02 +0000 2022  1502014184506093584  1502014184506093584
# 0  Thu Mar 10 19:51:56 +0000 2022  1502009376517005313  1502009376517005313
# 0  Thu Mar 10 12:40:21 +0000 2022  1501900768734973952  1501900768734973952
# 0  Thu Mar 10 00:21:19 +0000 2022  1501714781891346435  1501714781891346435
#
#                                                 text truncated entities  \
# 0  #Bengaluru After a long time (thanks to the #C...      True      NaN
# 0  @PTI_News China will keep playing this bogie a...     False      NaN
# 0  In view of the spread of new virus, \nChina ha...      True      NaN
# 0  @amitsurg So a minister will decide if the pre...      True      NaN
# 0  @jaideepsethiya @OpIndia_com Whatever the rank...      True      NaN
# 0  "Chinese cyberespionage group Mustang Panda ha...      True      NaN
# 0  @JackDetsch Well, China came first with #chine...     False      NaN
# 0          @UNICEFIndia Stay safe from #ChineseVirus     False      NaN
# 0  Latest evidence founded at US biological lab i...      True      NaN
# 0  America post-freedom:\n\nDay 414 of fake elect...      True      NaN
#
#   metadata                                             source  \
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
#
#   in_reply_to_status_id in_reply_to_status_id_str  ...  \
# 0                  None                      None  ...
# 0   1502219177850900480       1502219177850900480  ...
# 0                  None                      None  ...
# 0   1502258623673937920       1502258623673937920  ...
# 0   1502241867005673472       1502241867005673472  ...
# 0                  None                      None  ...
# 0   1502013087540559872       1502013087540559872  ...
# 0   1495299682381225991       1495299682381225991  ...
# 0                  None                      None  ...
# 0                  None                      None  ...
#
#   user.profile_use_background_image user.has_extended_profile  \
# 0                              True                      True
# 0                              True                      True
# 0                              True                     False
# 0                              True                     False
# 0                              True                     False
# 0                              True                      True
# 0                              True                     False
# 0                              True                     False
# 0                              True                     False
# 0                             False                     False
#
#   user.default_profile user.default_profile_image user.following  \
# 0                False                      False           None
# 0                False                      False           None
# 0                 True                      False           None
# 0                 True                      False           None
# 0                 True                      False           None
# 0                 True                      False           None
# 0                 True                      False           None
# 0                 True                      False           None
# 0                 True                      False           None
# 0                False                      False           None
#
#   user.follow_request_sent user.notifications user.translator_type  \
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
# 0                     None               None                 none
#
#   user.withheld_in_countries possibly_sensitive
# 0                         []                NaN
# 0                         []                NaN
# 0                         []                NaN
# 0                         []                NaN
# 0                         []                NaN
# 0                         []              False
# 0                         []                NaN
# 0                         []                NaN
# 0                         []                NaN
# 0                         []                NaN
#
# [10 rows x 75 columns]

# %%
df['geo'] == "None"
# Out:
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
# 0    False
# Name: geo, dtype: bool

# %%
# all columns available to us
df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities',
#        'metadata', 'source', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo',
#        'coordinates', 'place', 'contributors', 'is_quote_status',
#        'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang',
#        'entities.hashtags', 'entities.symbols', 'entities.user_mentions',
#        'entities.urls', 'metadata.iso_language_code', 'metadata.result_type',
#        'user.id', 'user.id_str', 'user.name', 'user.screen_name',
#        'user.location', 'user.description', 'user.url',
#        'user.entities.url.urls', 'user.entities.description.urls',
#        'user.protected', 'user.followers_count', 'user.friends_count',
#        'user.listed_count', 'user.created_at', 'user.favourites_count',
#        'user.utc_offset', 'user.time_zone', 'user.geo_enabled',
#        'user.verified', 'user.statuses_count', 'user.lang',
#        'user.contributors_enabled', 'user.is_translator',
#        'user.is_translation_enabled', 'user.profile_background_color',
#        'user.profile_background_image_url',
#        'user.profile_background_image_url_https',
#        'user.profile_background_tile', 'user.profile_image_url',
#        'user.profile_image_url_https', 'user.profile_banner_url',
#        'user.profile_link_color', 'user.profile_sidebar_border_color',
#        'user.profile_sidebar_fill_color', 'user.profile_text_color',
#        'user.profile_use_background_image', 'user.has_extended_profile',
#        'user.default_profile', 'user.default_profile_image', 'user.following',
#        'user.follow_request_sent', 'user.notifications',
#        'user.translator_type', 'user.withheld_in_countries',
#        'possibly_sensitive'],
#       dtype='object')

# %%
# Number of columns available to us
len(df.columns)
# Out:
# 75

# %% [markdown]
# The user has to explicitly share its location while tweeting for tweet.coordinates to be equal to the tweet exact location, so it makes sense many tweets will have empty coordinates.
#
# Here are the [GeoGuidelines](https://developer.twitter.com/en/developer-terms/geo-guidelines).
#
# There are two ways to get a location from Twitter; a geo-tag from a specific tweet, or a user’s location as part of their profile. According to Twitter, only 1–2% of tweets are geo-tagged hence it isn’t a great metric to be using; on the other hand a significant amount of users have a location in their profile, but they can enter whatever they want. Some are nice to people like us and will write ‘London, England’ or similar, while others are less useful, putting things like ‘My Parents Basement’.
#
#
# Let's scrape 50 tweets now and filter for those tweets that are located in the United States and the user shares their location.

# %%
# get tweets from the API
search_query = "#chinesevirus -filter:retweets"

# center of united states
latitude = "37.09024"
longitude = "-95.712891"
radius = "791mi"

tweets = tw.Cursor(api.search_tweets,
                  q = search_query,
                  lang = "en").items(50)

# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    print(tweet.text, '\n\n')
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# #Bengaluru After a long time (thanks to the #ChineseVirus) how about a #TweetUp
# (Venue can be decided based on the… https://t.co/sYRZceBf5c
#
#
# @PTI_News China will keep playing this bogie as #Putin has taken away entire attention from the #ChineseVirus.
#
#
# In view of the spread of new virus,
# China has imposed a lockdown in the north-eastern industrial center of Changch… https://t.co/zRaZbsZrGJ
#
#
# @amitsurg So a minister will decide if the prescription is right?
# The biggest tragedy following #ChineseVirus pande… https://t.co/fqMPoaZ2F1
#
#
# @jaideepsethiya @OpIndia_com Whatever the ranking we're No:1
#
# Terrorist exports, #ChineseVirus, gold and drug smugg… https://t.co/JRhm25NlNy
#
#
# "Chinese cyberespionage group Mustang Panda has been targeting European diplomats with an updated variant of the Pl… https://t.co/O5Gj8WHV5K
#
#
# @JackDetsch Well, China came first with #chinesevirus. Russia must think another thing for a surprise.
#
#
# @UNICEFIndia Stay safe from #ChineseVirus
#
#
# Latest evidence founded at US biological lab in Ukraine shows the fucking virus was made by fucking American. And o… https://t.co/t89DtNe0K5
#
#
# America post-freedom:
#
# Day 414 of fake election winners
#
# Week 103 of two weeks to flatten the curve
#
# #TrumpWon2020… https://t.co/V6KLmgTWe3
#
#
# @IngrahamAngle Biden team ok with new hashtag #PutinPriceHike but not with #ChineseVirus
#
#
# Scientist's have discovered that bombing and missile strikes can make you immune from #ChineseVirus so it's all coo… https://t.co/2jbiAi6HUq
#
#
# Boston college student loses legs and fingers after eating leftover Chinese food and developed life threatening sepsis !!
#
# #Chinesevirus
#
#
# With my very limited knowledge of geopolitics, here is my take.
#
# What happened to UK and France during 1960's Israe… https://t.co/3Rbzbrro19
#
#
# @sidhant WE DONT NEED CHINESE #CHINESEVIRUS WE NEVER TRUST CHINESE MR WANG YI @DrSJaishankar @PMOIndia @GovernmentRF @ChinaSpox_India
#
#
# @ESPNcricinfo Stay safe from #ChineseVirus everyone 😷
#
#
# Bit rich! #Wuhan #chinesevirus #COVID19 https://t.co/B5pFVsSeRo
#
#
# Over six million people have died globally so far from #ChineseVirus since the pandemic began! Why should MASS MURD… https://t.co/k1Lw4kOQtc
#
#
# Two years ago, this was our last normal week and no one knew it.
# #Chinesevirus
#
#
# @thepoliticalway @ReblochonMasque @AutoEngineerD @fbermingham Chinese name for #Tibet: "#Xizang" which means 'Weste… https://t.co/KQdffZkFrP
#
#
# @JM_Scindia Awesome.
# It's time to move on. #ChineseVirus is here to stay for longer time.
# Please discontinue all m… https://t.co/212MGWzZ5S
#
#
# What the fuckkkk are they doing?
# #chinaziVirus #chineseVirus #thisisChina
#
# #ccp is keen on finding joyfulness amid… https://t.co/m0nuTam5qr
#
#
# @nationalpost @MFA_China If you know it then ask @KremlinRussia_E to stop the war ... Or be ready for another pande… https://t.co/dmeYB2pOXT
#
#
# @zlj517 But you have created a #chinesevirus in your labs and didn't allow multilateral verifications  that the who… https://t.co/IWFl8pDkGo
#
#
# @ASBMilitary You should have raised this issue before  break out of #chinesevirus you choose to remain silent at that time.
#
#
# @CapitanBitcoin #DiaVictimasCovid19
# The day China released its deadly #Chinesevirus around the world, causing death… https://t.co/UbL312wcH5
#
#
# How Communist WHO Chief is Preparing World For China Takeover
#
# https://t.co/S8ajVNTvqm
#
# #WHOLiedPeopleDied… https://t.co/RWZFHsWZ3B
#
#
# America post-freedom:
#
# Day 412 of fake election winners
#
# Week 103 of two weeks to flatten the curve
#
# #TrumpWon2020… https://t.co/i4uZuvkmMa
#
#
# @globaltimesnews Since #chinesevirus mouthpiece is peddling fake news, why not report this to Twitter?
#
#
# @Nathan_Drake_1 @sukrusarac0glu @rohanbakshi08 @spectatorindex And before the outbreak of #ChineseVirus it was $2100+
#
#
# #NeverForget what the democrats were doing &amp; saying…(calling President Trump racist) while President Trump was taki… https://t.co/t6rnt7GNYV
#
#
# @spectatorindex No Caption
# #ChineseVirus
# #RussianUkrainianWar
# #Ukraine
# #PutinWarCriminal https://t.co/3aZzEny7H8
#
#
# @globaltimesnews #HoldChinaAccountable for #ChineseVirus or #XiVariant
#
# #FreeTibet #FreeHK #China #CCP #XiJinping… https://t.co/Vrpjjeg4nZ
#
#
# The #Variants of) #ChineseVirus STILL around, and evidence indicates that its awful effects on the body last much b… https://t.co/8DYKic4zXQ
#
#
# For the last 2 years the satanists have been telling us to #StopAsianHate because decent humans got mad about the… https://t.co/3vF5B6BtyI
#
#
# @jeetsidhu_ 😜 Fact is UN has no relevance in 2022… WHO UN Etc Etc lost all relevance in 2020 during #ChineseVirus t… https://t.co/6VVYWV9imI
#
#
# #Xitler has broken the record of #Hitler of reducing Human population of world by six millions with the help of its… https://t.co/vVU2J3jZzX
#
#
# @SkyNews Since when did China get the authority to tell anyone what to do. #ChineseVirus
#
#
# Chinese Virus Did Not Come From China Says Furious Chinese Leader
#
# https://t.co/PzhvbWYXKV
#
# #chinesevirus #xijinping https://t.co/Cef3K3TxRu
#
#
# @globaltimesnews Come on it's #ChineseVirus not Covid 19.
#
#
# America post-freedom:
#
# Day 410 of fake election winners
#
# Week 102 of two weeks to flatten the curve
#
# #TrumpWon2020… https://t.co/eLBYdYw6A0
#
#
# Good Morning Tweeter World 🌎!!! From Deerfield Beach - South FL - USA 🇺🇸!!! No more #ChineseVirus!!! https://t.co/fFNv6BYz8m
#
#
# Idk if you have noticed but feels like #ChineseVirus is a news of last century. Nobody is concerned about it now. C… https://t.co/z8M8kuBJmt
#
#
# @major_madhan No western countries want to participate in war and waste money. All are just coming out of… https://t.co/KtfoAlrIJ2
#
#
# @Law0573 @TimesNow F!_! ck #China ….. communism is cancer for Humanity. China killed millions on innocent people by… https://t.co/atE7z8lERD
#
#
# @Cernovich too moderate for you? #ChineseVirus #Covid #GOP2point0 #authoritians
#
#
# @DrTedros @WHO This guy #TedrosResign #Tedrosvirus #TedrosLiedPeopleDied #TedrosOut #ChinaLiedPeopleDie… https://t.co/U8K4PbeTpe
#
#
# Bring back the king of twitter 👑 #FakeNews #ChineseVirus https://t.co/iaNAE1WEII
#
#
# America post-freedom:
#
# Day 408 of fake election winners
#
# Week 102 of two weeks to flatten the curve
#
# #TrumpWon2020… https://t.co/QYkp4lCPnK
#
#
# Dude... Don't get me started with the amount of fat-ass Karens and washed up soccer moms who shrieked about the… https://t.co/egsppCVIEM
#
#
# Total Tweets fetched: 50

# %%
# Lets create a dataframe for our scraped tweets
df = pd.DataFrame(columns = tweets_copy[0]._json.keys())

for i in range(len(tweets_copy)):
    df = df.append(pd.json_normalize(tweets_copy[i]._json))
    
df.reset_index()
df
# Out:
#                        created_at                   id               id_str  \
# 0  Fri Mar 11 15:21:56 +0000 2022  1502303819740319746  1502303819740319746
# 0  Fri Mar 11 14:47:40 +0000 2022  1502295193806163968  1502295193806163968
# 0  Fri Mar 11 14:40:16 +0000 2022  1502293335062433793  1502293335062433793
# 0  Fri Mar 11 13:32:12 +0000 2022  1502276202635329538  1502276202635329538
# 0  Fri Mar 11 12:25:04 +0000 2022  1502259310587351041  1502259310587351041
# 0  Thu Mar 10 20:47:27 +0000 2022  1502023348464893955  1502023348464893955
# 0  Thu Mar 10 20:11:02 +0000 2022  1502014184506093584  1502014184506093584
# 0  Thu Mar 10 19:51:56 +0000 2022  1502009376517005313  1502009376517005313
# 0  Thu Mar 10 12:40:21 +0000 2022  1501900768734973952  1501900768734973952
# 0  Thu Mar 10 00:21:19 +0000 2022  1501714781891346435  1501714781891346435
# 0  Wed Mar 09 21:31:34 +0000 2022  1501672064972955652  1501672064972955652
# 0  Wed Mar 09 20:00:12 +0000 2022  1501649071353835525  1501649071353835525
# 0  Wed Mar 09 19:06:28 +0000 2022  1501635548498526208  1501635548498526208
# 0  Wed Mar 09 17:33:21 +0000 2022  1501612115945213959  1501612115945213959
# 0  Wed Mar 09 16:27:22 +0000 2022  1501595508174770177  1501595508174770177
# 0  Wed Mar 09 15:29:00 +0000 2022  1501580822335614977  1501580822335614977
# 0  Wed Mar 09 15:06:13 +0000 2022  1501575086607900673  1501575086607900673
# 0  Wed Mar 09 09:56:26 +0000 2022  1501497130321870851  1501497130321870851
# 0  Wed Mar 09 08:07:47 +0000 2022  1501469786542571521  1501469786542571521
# 0  Wed Mar 09 06:26:24 +0000 2022  1501444270284279812  1501444270284279812
# 0  Wed Mar 09 05:34:42 +0000 2022  1501431260027097088  1501431260027097088
# 0  Wed Mar 09 03:16:25 +0000 2022  1501396460579209219  1501396460579209219
# 0  Wed Mar 09 02:42:53 +0000 2022  1501388020284489732  1501388020284489732
# 0  Tue Mar 08 20:35:03 +0000 2022  1501295451462635522  1501295451462635522
# 0  Tue Mar 08 13:58:19 +0000 2022  1501195612049776650  1501195612049776650
# 0  Tue Mar 08 10:55:46 +0000 2022  1501149670764158979  1501149670764158979
# 0  Tue Mar 08 00:03:27 +0000 2022  1500985509233020929  1500985509233020929
# 0  Mon Mar 07 23:06:19 +0000 2022  1500971131158814727  1500971131158814727
# 0  Mon Mar 07 19:14:14 +0000 2022  1500912727384272900  1500912727384272900
# 0  Mon Mar 07 16:41:52 +0000 2022  1500874383312953350  1500874383312953350
# 0  Mon Mar 07 12:44:53 +0000 2022  1500814742885056512  1500814742885056512
# 0  Mon Mar 07 11:07:58 +0000 2022  1500790355930714112  1500790355930714112
# 0  Mon Mar 07 09:56:26 +0000 2022  1500772354460463106  1500772354460463106
# 0  Mon Mar 07 04:04:27 +0000 2022  1500683774207545350  1500683774207545350
# 0  Sun Mar 06 19:33:03 +0000 2022  1500555077018337280  1500555077018337280
# 0  Sun Mar 06 17:22:14 +0000 2022  1500522153451474949  1500522153451474949
# 0  Sun Mar 06 14:48:16 +0000 2022  1500483406022733825  1500483406022733825
# 0  Sun Mar 06 11:01:02 +0000 2022  1500426220609150979  1500426220609150979
# 0  Sun Mar 06 08:59:18 +0000 2022  1500395585169469440  1500395585169469440
# 0  Sun Mar 06 04:59:53 +0000 2022  1500335333652992002  1500335333652992002
# 0  Sun Mar 06 02:29:29 +0000 2022  1500297487877296130  1500297487877296130
# 0  Sat Mar 05 11:10:01 +0000 2022  1500066093930586114  1500066093930586114
# 0  Sat Mar 05 06:08:16 +0000 2022  1499990158044631040  1499990158044631040
# 0  Sat Mar 05 06:00:40 +0000 2022  1499988246104846337  1499988246104846337
# 0  Sat Mar 05 03:06:57 +0000 2022  1499944526101635073  1499944526101635073
# 0  Fri Mar 04 19:34:27 +0000 2022  1499830652920815620  1499830652920815620
# 0  Fri Mar 04 12:37:05 +0000 2022  1499725616035229701  1499725616035229701
# 0  Fri Mar 04 09:46:54 +0000 2022  1499682788856905729  1499682788856905729
# 0  Fri Mar 04 00:08:39 +0000 2022  1499537269925027843  1499537269925027843
# 0  Thu Mar 03 18:39:15 +0000 2022  1499454370286641161  1499454370286641161
#
#                                                 text truncated entities  \
# 0  #Bengaluru After a long time (thanks to the #C...      True      NaN
# 0  @PTI_News China will keep playing this bogie a...     False      NaN
# 0  In view of the spread of new virus, \nChina ha...      True      NaN
# 0  @amitsurg So a minister will decide if the pre...      True      NaN
# 0  @jaideepsethiya @OpIndia_com Whatever the rank...      True      NaN
# 0  "Chinese cyberespionage group Mustang Panda ha...      True      NaN
# 0  @JackDetsch Well, China came first with #chine...     False      NaN
# 0          @UNICEFIndia Stay safe from #ChineseVirus     False      NaN
# 0  Latest evidence founded at US biological lab i...      True      NaN
# 0  America post-freedom:\n\nDay 414 of fake elect...      True      NaN
# 0  @IngrahamAngle Biden team ok with new hashtag ...     False      NaN
# 0  Scientist's have discovered that bombing and m...      True      NaN
# 0  Boston college student loses legs and fingers ...     False      NaN
# 0  With my very limited knowledge of geopolitics,...      True      NaN
# 0  @sidhant WE DONT NEED CHINESE #CHINESEVIRUS WE...     False      NaN
# 0  @ESPNcricinfo Stay safe from #ChineseVirus eve...     False      NaN
# 0  Bit rich! #Wuhan #chinesevirus #COVID19 https:...     False      NaN
# 0  Over six million people have died globally so ...      True      NaN
# 0  Two years ago, this was our last normal week a...     False      NaN
# 0  @thepoliticalway @ReblochonMasque @AutoEnginee...      True      NaN
# 0  @JM_Scindia Awesome.\nIt's time to move on. #C...      True      NaN
# 0  What the fuckkkk are they doing? \n#chinaziVir...      True      NaN
# 0  @nationalpost @MFA_China If you know it then a...      True      NaN
# 0  @zlj517 But you have created a #chinesevirus i...      True      NaN
# 0  @ASBMilitary You should have raised this issue...     False      NaN
# 0  @CapitanBitcoin #DiaVictimasCovid19\nThe day C...      True      NaN
# 0  How Communist WHO Chief is Preparing World For...      True      NaN
# 0  America post-freedom:\n\nDay 412 of fake elect...      True      NaN
# 0  @globaltimesnews Since #chinesevirus mouthpiec...     False      NaN
# 0  @Nathan_Drake_1 @sukrusarac0glu @rohanbakshi08...     False      NaN
# 0  #NeverForget what the democrats were doing &am...      True      NaN
# 0  @spectatorindex No Caption \n#ChineseVirus \n#...     False      NaN
# 0  @globaltimesnews #HoldChinaAccountable for #Ch...      True      NaN
# 0  The #Variants of) #ChineseVirus STILL around, ...      True      NaN
# 0  For the last 2 years the satanists have been t...      True      NaN
# 0  @jeetsidhu_ 😜 Fact is UN has no relevance in 2...      True      NaN
# 0  #Xitler has broken the record of #Hitler of re...      True      NaN
# 0  @SkyNews Since when did China get the authorit...     False      NaN
# 0  Chinese Virus Did Not Come From China Says Fur...     False      NaN
# 0  @globaltimesnews Come on it's #ChineseVirus no...     False      NaN
# 0  America post-freedom:\n\nDay 410 of fake elect...      True      NaN
# 0  Good Morning Tweeter World 🌎!!! From Deerfield...     False      NaN
# 0  Idk if you have noticed but feels like #Chines...      True      NaN
# 0  @major_madhan No western countries want to par...      True      NaN
# 0  @Law0573 @TimesNow F!_! ck #China ….. communis...      True      NaN
# 0  @Cernovich too moderate for you? #ChineseVirus...     False      NaN
# 0  @DrTedros @WHO This guy #TedrosResign #Tedrosv...      True      NaN
# 0  Bring back the king of twitter 👑 #FakeNews #Ch...     False      NaN
# 0  America post-freedom:\n\nDay 408 of fake elect...      True      NaN
# 0  Dude... Don't get me started with the amount o...      True      NaN
#
#   metadata                                             source  \
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/#!/download/ipad" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="http://www.linkedin.com/" rel="nofoll...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="https://www.socialjukebox.com" rel="n...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://www.socialjukebox.com" rel="n...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="http://twitter.com/download/iphone" r...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="http://twitter.com/download/android" ...
# 0      NaN  <a href="https://mobile.twitter.com" rel="nofo...
# 0      NaN  <a href="http://twitter.com/download/android" ...
#
#   in_reply_to_status_id in_reply_to_status_id_str  ... place.place_type  \
# 0                  None                      None  ...              NaN
# 0   1502219177850900480       1502219177850900480  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1502258623673937920       1502258623673937920  ...              NaN
# 0   1502241867005673472       1502241867005673472  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1502013087540559872       1502013087540559872  ...              NaN
# 0   1495299682381225991       1495299682381225991  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1501278342351409153       1501278342351409153  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1500801463299493888       1500801463299493888  ...              NaN
# 0   1501580258080096258       1501580258080096258  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1501432323891347458       1501432323891347458  ...              NaN
# 0   1501168243095977985       1501168243095977985  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1501208294312099847       1501208294312099847  ...              NaN
# 0   1497413764941234177       1497413764941234177  ...              NaN
# 0   1501186294961082369       1501186294961082369  ...              NaN
# 0   1501124960676425731       1501124960676425731  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1500862498425405441       1500862498425405441  ...              NaN
# 0   1500873474013032448       1500873474013032448  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1500789076487970818       1500789076487970818  ...              NaN
# 0   1500562010253189125       1500562010253189125  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1500518970356551680       1500518970356551680  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1500398733544071169       1500398733544071169  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1500325172502405125       1500325172502405125  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0   1499974191465963521       1499974191465963521  ...              NaN
# 0   1499942002355363843       1499942002355363843  ...             city
# 0   1499631198481502209       1499631198481502209  ...              NaN
# 0   1479503151577378823       1479503151577378823  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
# 0                  None                      None  ...              NaN
#
#   place.name   place.full_name place.country_code place.country  \
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0  New Delhi  New Delhi, India                 IN         India
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
# 0        NaN               NaN                NaN           NaN
#
#   place.contained_within place.bounding_box.type  \
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                     []                 Polygon
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
# 0                    NaN                     NaN
#
#                       place.bounding_box.coordinates  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  [[[76.84252, 28.397657], [77.347652, 28.397657...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#   quoted_status.quoted_status_id quoted_status.quoted_status_id_str
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                            NaN                                NaN
# 0                   1.499419e+18                1499418852903501832
#
# [50 rows x 166 columns]

# %%
df['coordinates']
# Out:
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# 0    None
# Name: coordinates, dtype: object

# %% [markdown]
# It seems as though there are few users that provide their location. I'll have to find another way to query for users that do share their location.

# %% [markdown]
# ## Questions Moving Forward
#
# 1. Temporal Trends: what time frame are we looking at? The research publication gathered tweets one week before, and one week after Trump made his first tweet referring to Covid-19 as the "Chinese Virus".
# 2. To build on point 1, if we want to access tweets archived prior to one week ago, we will need to apply for the Academic Research product. The product is free, and will grant us greater flexibility with our work. Of course, I plan to use this privilege reasonably, and make only small requests until we've further developed our project.
# 3. What notable sentiments are we targetting in the tweets? It is one thing to gather all tweets with the hashtag "#chinesevirus" or "#covid19". The article provided considers a tweet anti-Asian if one of the four conditions were met,
# - 1. Was opposed to or hostile toward the region, the people, or culture of Asia;
# - 2. Demonstrated a general fear, mistrust, and hatred of Asian ethnic groups;
# - 3. Supported restrictions on Asian immigration
# - 4. Used derogatory language or condoned punishments toward Asian countries or their people
#
# Continuing on point 3, what sentiments are we targeting? From there we can establish methods to extract those sentiments from the tweets and filter for/against them.
#
# 4. Sentiment analysis is a natural language processing technique in Python. We can grade the sentiment of a string of text on a scale of [-1, 1], -1 indicating a negative sentiment, and 1 indicating a positive sentiment, while 0 indicated neutrality. Let's keep this in mind moving forward.
